# %% [markdown]
# # OpenAI 모델 사용

# %% [markdown]
# ## OpenAI 공식문서
# - https://platform.openai.com/docs/quickstart?language=python

# %%
# API 키로딩
from dotenv import load_dotenv
import os

load_dotenv('.env', override=True)
OPENAI_API_KEY = os.environ["OPENAI_API_KEY"]
# print("OPENAI_API_KEY:", OPENAI_API_KEY)

# %%
from openai import OpenAI
client = OpenAI()

response = client.responses.create(
    model="gpt-5-nano",
    input="AI Agent에 대해 설명해줘"
)

print(response.output_text)
# Out:
# 다음은 AI 에이전트에 대한 간단하고 핵심적인 설명입니다.
#
# 1) 정의
# - AI 에이전트는 환경을 관찰(sense)하고, 그 관찰에 따라 행동(action)하는 자율적인 시스템입니다. 보통 특정 목표를 달성하거나 성능 지표(보상)를 최대화하도록 설계됩니다.
# - 작동 방식은 일반적으로 관찰→의사결정→행동의 순환(센싱-판단-행동 루프)으로 이루어집니다.
#
# 2) 핵심 구성요소
# - 감지/관측( perception ): 센서나 데이터 소스(비전, 음성, 로그 등)로 환경 정보를 얻습니다.
# - 내부 상태/지식( memory, 모델 ): 환경에 대한 기억이나 세계 모델, 신념 등을 보유합니다.
# - 의사결정/계획( decisionmaking, planning ): 관측 정보를 바탕으로 무엇을 할지 결정합니다. 규칙 기반, 탐색/계획, 또는 학습된 정책일 수 있습니다.
# - 행동/실행( action ): 결정된 결과를 실제 액션으로 환경에 반영합니다.
# - 학습/적응( learning ): 과거의 경험으로 성능을 개선하고 정책을 업데이트합니다.
# - 성능 평가( evaluation ): 목표 달성도, 효율성, 안전성 등을 측정합니다.
#
# 3) 대표적인 에이전트 유형
# - 반사적 에이전트(Reflex agent): 현재 관측에 즉시 반응하는 단순한 형태.
# - 모델 기반 반사 에이전트(Model-based): 내부 상태를 유지해 과거 정보를 참고합니다.
# - 목표 지향 에이전트(Goal-based): 목표를 달성하기 위해 필요한 상태를 탐색합니다.
# - 유틸리티 기반 에이전트(Utility-based): 다양한 상태에 대해 선호도(유틸리티)를 계산해 최적의 행동을 선택합니다.
# - 학습 에이전트(Learning agent): 경험으로 학습하고 정책을 개선합니다.
# - 다중 에이전트 시스템(Multi-agent systems): 여러 에이전트가 협력하거나 경쟁하는 환경에서 작동합니다.
#
# 4) 자주 쓰이는 학습/이론적 접근
# - 지도학습/비지도학습: 감지나 인식 모듈을 학습하는 데 사용됩니다.
# - 강화학습(RL): 에이전트가 환경과의 상호작용을 통해 보상을 최대화하는 정책을 학습합니다.
# - 제어/계획: 규칙이나 목표에 따라 행동 계획을 세웁니다(예: A*, PDDL 플래너).
# - 모형 기반 학습: 환경의 동작 원리를 모델로 추정하고 이를 바탕으로 의사결정을 보완합니다.
# - 비슷한 맥락의 이론: 의사결정 이론의 BDI( beliefs-desires-intentions) 모델 등.
#
# 5) 환경 속성에 따른 설계 시 고려점
# - 결정적 대 확률적(deterministic vs stochastic)
# - 완전 관찰 vs 부분 관찰(fully vs partially observable)
# - 에피소드형 vs 연속형(episodic vs continuing)
# - 단일 에이전트 vs 다중 에이전트(협력, 경쟁, 협상 등)
#
# 6) 실제 예시 분야
# - 가상 비서/챗봇: 질의 응답, 일정 관리, 정보 검색 등.
# - 로봇/산업 자동화: 창고 로봇, 자율주행 차량, 제조 로봇 등.
# - 게임 AI: NPC의 의사결정, 전략 시뮬레이션.
# - 금융/트레이딩 봇: 시장 데이터 분석과 자동 주문 실행.
# - 소프트웨어 에이전트: 자동화된 워크플로우, 모니터링/경고 시스템.
# - 시뮬레이션 기반 연구: 에이전트 기반 모델링(ABM)으로 사회현상이나 생태계 연구.
#
# 7) 구축 흐름(간단한 가이드)
# - 목표와 환경 정의: 무엇을 달성하고 어떤 환경에서 작동할지 결정.
# - 에이전트 아키텍처 선택: 규칙 기반, 계획 중심, 학습 기반 중 적합한 것을 택합니다.
# - 관측/행동 인터페이스 구현: 입력 데이터 포맷과 외부 시스템과의 연결 구축.
# - 의사결정 엔진 구현: 규칙, 계획 알고리즘, 또는 학습 정책을 구성.
# - 학습 요소 추가(필요 시): 강화학습이나 지도학습으로 성능 향상.
# - 시뮬레이션/테스트: 안전한 환경에서 검증, 성능/안정성 점검.
# - 배포 및 모니터링: 실서비스에서의 로그 수집, 재학습/개선 루프 운영.
# - 안전성/윤리성 고려: 데이터 프라이버시, 편향 방지, 오작동 대비 체계 마련.
#
# 8) 자주 쓰는 도구/프레임워크
# - 강화학습/정책 학습: Stable Baselines3, TensorFlow Agents, RLlib
# - 다중 에이전트 환경: PettingZoo
# - 에이전트 기반 모델링: Mesa, NetLogo
# - 챗봇/대화형 에이전트: Rasa, Dialogflow, Microsoft Bot Framework
# - 로봇/제어: ROS(로봇 운영 체제)
#
# 9) 주의할 점
# - 목표 정의의 정확성: 잘못된 보상이나 목표를 설정하면 원치 않는 행동이 나올 수 있습니다(보상 설계의 문제).
# - 안전성 및 신뢰성: 예측 불가능한 입력이나 공격에 대한 강건성 필요.
# - 데이터 편향/프라이버시: 학습 데이터의 편향이나 민감 정보 처리 주의.
# - 설명가능성과 투명성: 왜 어떤 결정을 내렸는지 설명이 필요한 상황이 많습니다.
# - 계산 자원과 운영 비용: 대규모 학습이나 다중 에이전트 시스템은 자원 소모가 큽니다.
#
# 필요하신 구체 영역이 있다면 알려주세요
# - 이론적 원리(정의, 수학적 모델) 위주로 더 자세히
# - 구축 예제(간단한 코드 예제나 아키텍처 다이어그램)
# - 특정 도메인에 맞춘 사례 분석
# - 다중 에이전트 시스템이나 협력/경쟁 시나리오에 대한 설명
#
# 어떤 부분부터 더 자세히 보고 싶으신가요?

# %% [markdown]
# # 구글의 학습 모델 사용
# ## 구글 gemini 공식문서
# - https://ai.google.dev/gemini-api/docs/quickstart?hl=ko

# %%
from dotenv import load_dotenv
import os

load_dotenv('.env', override=True)
GEMINI_API_KEY = os.environ["GEMINI_API_KEY"]
# print("GEMINI_API_KEY:", GEMINI_API_KEY)

# %%
from google import genai

# The client gets the API key from the environment variable `GEMINI_API_KEY`.
client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash", 
    contents="AI Agent에 대해 설명해줘"
)

print(response.text)
# Out:
# 'AI 에이전트(AI Agent)'는 인공지능 분야에서 매우 중요한 개념으로, **환경을 인식(Perceive)하고, 추론(Reason)하여, 목표를 달성하기 위해 행동(Act)하는 자율적인 존재**를 의미합니다. 단순히 데이터를 처리하는 AI 모델을 넘어, 주변 환경과 상호작용하며 특정 목적을 달성하려는 주체성을 가진 AI 시스템이라고 할 수 있습니다.
#
# 좀 더 자세히 설명해 드릴게요.
#
# ### AI 에이전트의 핵심 구성 요소 (PEAS Framework)
#
# AI 에이전트는 일반적으로 다음과 같은 4가지 핵심 구성 요소를 가집니다.
#
# 1.  **지각 (Perception):** 에이전트가 환경으로부터 정보를 받아들이는 능력입니다. 센서(카메라, 마이크, 온도계 등)를 통해 물리적 환경을 인식하거나, API 호출, 데이터베이스 조회 등을 통해 디지털 환경을 인식할 수 있습니다.
#     *   **예시:** 자율주행차의 카메라가 도로 표지판을 인식하고, 마이크가 주변 소리를 감지하며, 레이더/라이다가 주변 차량과 사물의 위치를 파악하는 것.
#
# 2.  **환경 (Environment):** 에이전트가 작동하고 상호작용하는 공간입니다. 물리적 환경(로봇이 움직이는 실제 공간)일 수도 있고, 디지털 환경(소프트웨어 에이전트가 작동하는 웹사이트, 운영체제 등)일 수도 있습니다.
#     *   **예시:** 자율주행차의 '도로' 환경, 챗봇의 '대화 인터페이스' 환경, 게임 AI의 '가상 게임 세계' 환경.
#
# 3.  **행동 (Action):** 에이전트가 목표를 달성하기 위해 환경에 영향을 미치는 활동입니다. 로봇 팔을 움직이거나, 버튼을 누르거나, 이메일을 보내거나, 데이터베이스에 정보를 기록하는 등의 모든 행위를 포함합니다.
#     *   **예시:** 자율주행차가 핸들을 돌리고, 브레이크를 밟고, 가속 페달을 조작하는 것.
#
# 4.  **목표 (Goals):** 에이전트가 달성하고자 하는 목적입니다. "목적지까지 안전하게 운전하기", "사용자의 질문에 정확하게 답변하기", "가장 높은 점수 얻기" 등이 될 수 있습니다. 에이전트의 모든 의사결정과 행동은 이 목표를 중심으로 이루어집니다.
#     *   **예시:** 자율주행차의 '목적지까지 탑승자를 안전하게 이동시키기'라는 목표.
#
# 이 4가지 요소는 서로 유기적으로 연결되어 **"지각 → 추론/의사결정 → 행동 → 다시 지각"**의 반복적인 루프를 형성하며 에이전트가 자율적으로 작동하도록 만듭니다.
#
# ### AI 에이전트의 주요 특징
#
# *   **자율성 (Autonomy):** 스스로 의사결정하고 행동합니다.
# *   **반응성 (Reactivity):** 환경 변화에 따라 적절하게 반응합니다.
# *   **능동성 (Proactiveness):** 목표 달성을 위해 스스로 행동을 시작하고 주도합니다.
# *   **사회성 (Social ability):** (필요한 경우) 다른 에이전트나 사람과 상호작용합니다.
# *   **학습 능력 (Learning ability):** 경험을 통해 성능을 개선합니다.
#
# ### AI 에이전트의 유형 (지능 수준에 따라)
#
# 1.  **단순 반사 에이전트 (Simple Reflex Agent):** 현재의 지각 상태만을 보고 미리 정해진 규칙(If-Then rule)에 따라 행동합니다. 기억이나 환경 모델이 없습니다. (예: 방 온도가 특정 온도 이상이면 에어컨 켜기)
# 2.  **모델 기반 반사 에이전트 (Model-based Reflex Agent):** 환경의 현재 상태뿐만 아니라 과거의 지각을 바탕으로 환경의 내부 모델(즉, 세상이 어떻게 돌아가는지에 대한 이해)을 구축하고 이를 기반으로 행동합니다. (예: 자율주행차가 주변 도로 상황과 교통 흐름을 기억하며 주행)
# 3.  **목표 기반 에이전트 (Goal-based Agent):** 목표를 명시적으로 가지고 있으며, 현재 상태에서 목표에 도달하기 위한 행동 시퀀스를 탐색합니다. (예: 특정 목적지까지 가는 최적 경로를 찾는 내비게이션 시스템)
# 4.  **유틸리티 기반 에이전트 (Utility-based Agent):** 목표가 여러 개이거나, 목표 달성 방식이 다양할 때 각 행동의 '유용성(Utility)'을 평가하여 가장 만족스러운 결과를 가져올 행동을 선택합니다. (예: 개인 비서 AI가 사용자의 일정, 선호도, 교통 상황 등을 고려하여 최적의 약속 시간을 제안)
# 5.  **학습 에이전트 (Learning Agent):** 경험을 통해 에이전트의 성능을 개선하고, 환경에 적응하며 발전합니다. (예: 강화 학습을 통해 게임 실력을 향상시키는 게임 AI)
#
# ### 최신 LLM(대규모 언어 모델) 기반 AI 에이전트
#
# 최근에는 ChatGPT와 같은 LLM이 AI 에이전트의 '뇌' 역할을 하면서 그 중요성이 더욱 커지고 있습니다. LLM 자체는 단순히 텍스트를 생성하는 모델이지만, 여기에 다음과 같은 구성 요소를 추가하면 강력한 AI 에이전트가 될 수 있습니다.
#
# *   **도구(Tools) 사용 능력:** LLM이 외부 API(검색 엔진, 계산기, 코드 인터프리터, 데이터베이스 등)를 호출하여 정보를 얻거나 특정 작업을 수행하는 능력.
# *   **기억(Memory) 기능:** 대화 내용, 과거 경험, 학습된 지식 등을 기억하여 일관성 있고 맥락에 맞는 행동을 할 수 있도록 하는 기능.
# *   **계획(Planning) 및 자기 성찰(Self-reflection) 능력:** 복잡한 목표를 작은 단계로 나누고, 각 단계의 성공 여부를 평가하며, 필요시 계획을 수정하는 능력.
#
# **예시:** LLM 기반 AI 에이전트가 "최신 경제 동향에 대해 조사하고 보고서를 작성해줘"라는 명령을 받으면,
# 1.  **계획:** "조사 → 요약 → 보고서 작성"으로 단계를 나눕니다.
# 2.  **도구 사용:** 검색 엔진 도구를 사용하여 최신 경제 뉴스 및 통계 자료를 찾아봅니다.
# 3.  **지각 및 추론:** 검색 결과를 읽고 핵심 내용을 추출하고 요약합니다.
# 4.  **행동:** 요약된 내용을 바탕으로 보고서 초안을 작성합니다.
# 5.  **자기 성찰:** 보고서가 요구 사항을 잘 충족하는지 검토하고, 부족한 부분이 있다면 추가 조사를 하거나 내용을 수정합니다.
#
# 결론적으로 AI 에이전트는 **자율적으로 환경과 상호작용하며 특정 목표를 달성하는 지능적인 시스템**을 일컫는 말이며, 앞으로 인공지능 기술이 발전함에 따라 우리의 일상과 산업 전반에 걸쳐 더욱 다양한 형태로 나타날 것입니다.

# %%
# 마크다운으로 출력하는 방법
from rich.console import Console
from rich.markdown import Markdown
# 마크다운 렌더링
md = Markdown(response.text)
console = Console()
console.print(md)
# Out:
# 'AI 에이전트(AI Agent)'는 인공지능 분야에서 매우 중요한 개념으로, 환경을 인식(Perceive)하고, 추론(Reason)하여,
# 목표를 달성하기 위해 행동(Act)하는 자율적인 존재를 의미합니다. 단순히 데이터를 처리하는 AI 모델을 넘어, 주변 환경과
# 상호작용하며 특정 목적을 달성하려는 주체성을 가진 AI 시스템이라고 할 수 있습니다.
#
# 좀 더 자세히 설명해 드릴게요.
#
#                                    AI 에이전트의 핵심 구성 요소 (PEAS Framework)
#
# AI 에이전트는 일반적으로 다음과 같은 4가지 핵심 구성 요소를 가집니다.
#
#  1 지각 (Perception): 에이전트가 환경으로부터 정보를 받아들이는 능력입니다. 센서(카메라, 마이크, 온도계 등)를 통해
#    물리적 환경을 인식하거나, API 호출, 데이터베이스 조회 등을 통해 디지털 환경을 인식할 수 있습니다.
#     • 예시: 자율주행차의 카메라가 도로 표지판을 인식하고, 마이크가 주변 소리를 감지하며, 레이더/라이다가 주변
#       차량과 사물의 위치를 파악하는 것.
#  2 환경 (Environment): 에이전트가 작동하고 상호작용하는 공간입니다. 물리적 환경(로봇이 움직이는 실제 공간)일 수도
#    있고, 디지털 환경(소프트웨어 에이전트가 작동하는 웹사이트, 운영체제 등)일 수도 있습니다.
#     • 예시: 자율주행차의 '도로' 환경, 챗봇의 '대화 인터페이스' 환경, 게임 AI의 '가상 게임 세계' 환경.
#  3 행동 (Action): 에이전트가 목표를 달성하기 위해 환경에 영향을 미치는 활동입니다. 로봇 팔을 움직이거나, 버튼을
#    누르거나, 이메일을 보내거나, 데이터베이스에 정보를 기록하는 등의 모든 행위를 포함합니다.
#     • 예시: 자율주행차가 핸들을 돌리고, 브레이크를 밟고, 가속 페달을 조작하는 것.
#  4 목표 (Goals): 에이전트가 달성하고자 하는 목적입니다. "목적지까지 안전하게 운전하기", "사용자의 질문에 정확하게
#    답변하기", "가장 높은 점수 얻기" 등이 될 수 있습니다. 에이전트의 모든 의사결정과 행동은 이 목표를 중심으로
#    이루어집니다.
#     • 예시: 자율주행차의 '목적지까지 탑승자를 안전하게 이동시키기'라는 목표.
#
# 이 4가지 요소는 서로 유기적으로 연결되어 **"지각 → 추론/의사결정 → 행동 → 다시 지각"**의 반복적인 루프를 형성하며
# 에이전트가 자율적으로 작동하도록 만듭니다.
#
#                                               AI 에이전트의 주요 특징
#
#  • 자율성 (Autonomy): 스스로 의사결정하고 행동합니다.
#  • 반응성 (Reactivity): 환경 변화에 따라 적절하게 반응합니다.
#  • 능동성 (Proactiveness): 목표 달성을 위해 스스로 행동을 시작하고 주도합니다.
#  • 사회성 (Social ability): (필요한 경우) 다른 에이전트나 사람과 상호작용합니다.
#  • 학습 능력 (Learning ability): 경험을 통해 성능을 개선합니다.
#
#                                        AI 에이전트의 유형 (지능 수준에 따라)
#
#  1 단순 반사 에이전트 (Simple Reflex Agent): 현재의 지각 상태만을 보고 미리 정해진 규칙(If-Then rule)에 따라
#    행동합니다. 기억이나 환경 모델이 없습니다. (예: 방 온도가 특정 온도 이상이면 에어컨 켜기)
#  2 모델 기반 반사 에이전트 (Model-based Reflex Agent): 환경의 현재 상태뿐만 아니라 과거의 지각을 바탕으로 환경의
#    내부 모델(즉, 세상이 어떻게 돌아가는지에 대한 이해)을 구축하고 이를 기반으로 행동합니다. (예: 자율주행차가 주변
#    도로 상황과 교통 흐름을 기억하며 주행)
#  3 목표 기반 에이전트 (Goal-based Agent): 목표를 명시적으로 가지고 있으며, 현재 상태에서 목표에 도달하기 위한 행동
#    시퀀스를 탐색합니다. (예: 특정 목적지까지 가는 최적 경로를 찾는 내비게이션 시스템)
#  4 유틸리티 기반 에이전트 (Utility-based Agent): 목표가 여러 개이거나, 목표 달성 방식이 다양할 때 각 행동의
#    '유용성(Utility)'을 평가하여 가장 만족스러운 결과를 가져올 행동을 선택합니다. (예: 개인 비서 AI가 사용자의 일정,
#    선호도, 교통 상황 등을 고려하여 최적의 약속 시간을 제안)
#  5 학습 에이전트 (Learning Agent): 경험을 통해 에이전트의 성능을 개선하고, 환경에 적응하며 발전합니다. (예: 강화
#    학습을 통해 게임 실력을 향상시키는 게임 AI)
#
#                                     최신 LLM(대규모 언어 모델) 기반 AI 에이전트
#
# 최근에는 ChatGPT와 같은 LLM이 AI 에이전트의 '뇌' 역할을 하면서 그 중요성이 더욱 커지고 있습니다. LLM 자체는 단순히
# 텍스트를 생성하는 모델이지만, 여기에 다음과 같은 구성 요소를 추가하면 강력한 AI 에이전트가 될 수 있습니다.
#
#  • 도구(Tools) 사용 능력: LLM이 외부 API(검색 엔진, 계산기, 코드 인터프리터, 데이터베이스 등)를 호출하여 정보를
#    얻거나 특정 작업을 수행하는 능력.
#  • 기억(Memory) 기능: 대화 내용, 과거 경험, 학습된 지식 등을 기억하여 일관성 있고 맥락에 맞는 행동을 할 수 있도록
#    하는 기능.
#  • 계획(Planning) 및 자기 성찰(Self-reflection) 능력: 복잡한 목표를 작은 단계로 나누고, 각 단계의 성공 여부를
#    평가하며, 필요시 계획을 수정하는 능력.
#
# 예시: LLM 기반 AI 에이전트가 "최신 경제 동향에 대해 조사하고 보고서를 작성해줘"라는 명령을 받으면,
#
#  1 계획: "조사 → 요약 → 보고서 작성"으로 단계를 나눕니다.
#  2 도구 사용: 검색 엔진 도구를 사용하여 최신 경제 뉴스 및 통계 자료를 찾아봅니다.
#  3 지각 및 추론: 검색 결과를 읽고 핵심 내용을 추출하고 요약합니다.
#  4 행동: 요약된 내용을 바탕으로 보고서 초안을 작성합니다.
#  5 자기 성찰: 보고서가 요구 사항을 잘 충족하는지 검토하고, 부족한 부분이 있다면 추가 조사를 하거나 내용을
#    수정합니다.
#
# 결론적으로 AI 에이전트는 자율적으로 환경과 상호작용하며 특정 목표를 달성하는 지능적인 시스템을 일컫는 말이며,
# 앞으로 인공지능 기술이 발전함에 따라 우리의 일상과 산업 전반에 걸쳐 더욱 다양한 형태로 나타날 것입니다.

# %% [markdown]
# 여러 밴더들의 학습모델을 접근할 수 있는 표준 API가 필요함.

# %% [markdown]
# # langchain 실습
# ## 공식문서
# - https://docs.langchain.com/oss/python/langchain/install

# %%
import langchain
langchain.__version__
# Out:
# '1.2.0'

# %%
# 필요한 API 키로딩
from dotenv import load_dotenv
import os

load_dotenv('.env', override=True)
OPENAI_API_KEY = os.environ["OPENAI_API_KEY"]
GEMINI_API_KEY = os.environ["GEMINI_API_KEY"]
# print("OPENAI_API_KEY:", OPENAI_API_KEY)
# print("GEMINI_API_KEY:", GEMINI_API_KEY)

# %% [markdown]
# ## langchain으로 OpenAI GPT 모델 사용

# %% [markdown]
# - 라이브러리 설치 필요
# ```
# pip install -Uq langchain-openai
# ```

# %%
from langchain_openai import ChatOpenAI

# 모델 초기화
llm = ChatOpenAI(
    model="gpt-4o",  # 또는 "gpt-4o-mini", "gpt-4-turbo", "gpt-3.5-turbo"
    temperature=0.7,
    max_tokens=None,
    timeout=None,
    max_retries=2
)

# %%
# 간단한 질문
response = llm.invoke("AI Agent에 대해 설명해줘")

# %%
print(response.content)
# Out:
# AI 에이전트는 특정 작업이나 목표를 수행하기 위해 설계된 인공지능 시스템입니다. 이러한 에이전트는 환경을 인식하고, 그 정보를 바탕으로 의사결정을 내리며, 행동을 수행하여 목표를 달성하려고 합니다. AI 에이전트는 자율적으로 작동할 수 있으며, 여러 분야에서 다양한 형태로 활용되고 있습니다.
#
# AI 에이전트의 기본 구성 요소는 다음과 같습니다:
#
# 1. **환경 감지**: 에이전트는 센서나 입력 데이터를 통해 주변 환경에 대한 정보를 수집합니다. 이 정보는 에이전트가 현재 상태를 이해하고 결정하는 데 사용됩니다.
#
# 2. **의사결정**: 수집된 정보를 바탕으로 에이전트는 목표를 달성하기 위해 어떤 행동을 취할지 결정합니다. 이 과정은 규칙 기반 시스템, 머신 러닝 알고리즘, 강화 학습 등 다양한 방법을 통해 이루어질 수 있습니다.
#
# 3. **행동 수행**: 결정된 행동을 실제로 수행하여 환경에 영향을 미칩니다. 이는 로봇 팔의 움직임일 수도 있고, 소프트웨어 프로그램에서의 데이터 처리일 수도 있습니다.
#
# 4. **피드백 루프**: 에이전트는 자신의 행동 결과를 모니터링하고, 이를 통해 학습하고 적응합니다. 이를 통해 시간이 지남에 따라 성능을 향상시킬 수 있습니다.
#
# AI 에이전트는 자율주행차, 가상 비서, 게임 AI, 산업 자동화 등 다양한 분야에서 사용됩니다. 각각의 분야에서는 특정 요구사항에 맞춰 에이전트가 설계되고 최적화됩니다.

# %% [markdown]
# ## langchain으로 구글 모델 사용하기

# %% [markdown]
# - LangChain Google GenAI 패키지 설치
# ```
# pip install langchain-google-genai
# ```

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# 모델 초기화
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",  # 최신 모델
    temperature=0.7,
    max_tokens=None,
    timeout=None,
    max_retries=2
)

# %%
# 간단한 질문
response = llm.invoke("AI Agent에 대해 설명해줘")

# %%
print(response.content)
# Out:
# AI 에이전트는 특정 작업이나 목표를 수행하기 위해 설계된 인공지능 시스템입니다. 이러한 에이전트는 환경을 인식하고, 그 정보를 바탕으로 의사결정을 내리며, 행동을 수행하여 목표를 달성하려고 합니다. AI 에이전트는 자율적으로 작동할 수 있으며, 여러 분야에서 다양한 형태로 활용되고 있습니다.
#
# AI 에이전트의 기본 구성 요소는 다음과 같습니다:
#
# 1. **환경 감지**: 에이전트는 센서나 입력 데이터를 통해 주변 환경에 대한 정보를 수집합니다. 이 정보는 에이전트가 현재 상태를 이해하고 결정하는 데 사용됩니다.
#
# 2. **의사결정**: 수집된 정보를 바탕으로 에이전트는 목표를 달성하기 위해 어떤 행동을 취할지 결정합니다. 이 과정은 규칙 기반 시스템, 머신 러닝 알고리즘, 강화 학습 등 다양한 방법을 통해 이루어질 수 있습니다.
#
# 3. **행동 수행**: 결정된 행동을 실제로 수행하여 환경에 영향을 미칩니다. 이는 로봇 팔의 움직임일 수도 있고, 소프트웨어 프로그램에서의 데이터 처리일 수도 있습니다.
#
# 4. **피드백 루프**: 에이전트는 자신의 행동 결과를 모니터링하고, 이를 통해 학습하고 적응합니다. 이를 통해 시간이 지남에 따라 성능을 향상시킬 수 있습니다.
#
# AI 에이전트는 자율주행차, 가상 비서, 게임 AI, 산업 자동화 등 다양한 분야에서 사용됩니다. 각각의 분야에서는 특정 요구사항에 맞춰 에이전트가 설계되고 최적화됩니다.
